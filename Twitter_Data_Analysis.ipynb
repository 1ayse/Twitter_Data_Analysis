# %% [markdown]
# <a href="https://colab.research.google.com/github/1ayse/Twitter_Data_Analysis/blob/main/Twitter_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Twitter Data Analysis

# The streaming API only allows real time data collection (keywords, userids, locations etc)

# %%
import os
from tweepy import OAuthHandler, API
from dotenv import load_dotenv

load_dotenv()  # .env dosyasını yükler

consumer_key = os.getenv("CONSUMER_KEY")
consumer_secret = os.getenv("CONSUMER_SECRET")
access_token = os.getenv("ACCESS_TOKEN")
access_token_secret = os.getenv("ACCESS_TOKEN_SECRET")

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = API(auth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4243296622.py in <cell line: 0>()
#      10 access_token_secret = os.getenv("ACCESS_TOKEN_SECRET")
#      11
# ---> 12 auth = OAuthHandler(consumer_key, consumer_secret)
#      13 auth.set_access_token(access_token, access_token_secret)
#      14 api = API(auth)
#
# /usr/local/lib/python3.12/dist-packages/tweepy/auth.py in __init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
#     122             DeprecationWarning
#     123         )
# --> 124         super().__init__(consumer_key, consumer_secret, access_token,
#     125                          access_token_secret, callback)
#     126
#
# /usr/local/lib/python3.12/dist-packages/tweepy/auth.py in __init__(self, consumer_key, consumer_secret, access_token, access_token_secret, callback)
# ...
